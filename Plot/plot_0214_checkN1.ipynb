# %% [markdown]
# # MNIST

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.cm as cm
import os
import seaborn as sns
import glob
import natsort

# %%
def get_concat(foldername, seeds):
    for i, seed in enumerate(seeds):
        if i == 0: data = pd.read_csv(os.path.join(save_path,foldername,"s{}.csv".format(seed)))
        else: 
            try: 
                data = pd.concat([data, pd.read_csv(os.path.join(save_path,foldername,"s{}.csv".format(seed)))])
            except:
                pass
    # print(foldername, len(data))
    return data

def get_concat_glob(paths):
    data_ = []
    for i, path in enumerate(paths):
        data = pd.read_csv(path)
        data["Mode"] = data["mode"] + data["gn"].astype(str)
        if "LR" in path:
            data["LR"] = float(path.split("LR")[1][:3])
        else:
            data["LR"] = 0.1
        if "G11" in path:
            data["Mode"] = "G11"
            if "Lin" in path:
                data["Decay"] = "GN_Lin"
            else:
                data["Decay"] = "GN_No"
        else:
            data["Decay"] = "No"
        if "G00" in path or "G11" in path or "G01" in path:
             pass
        else:
            continue
        
        if "G01" in path:
            data["Mode"] = "G01"

        if "N1-P" in path and "G00" in path:
            data["Mode"] = "FedAvg_F"
            # print(path)

        if "N1-P" in path and "G01" in path:
            data["Mode"] = "FedGN_F"
            # print(path)


        # print(path)
        
        if len(data_) == 0: 
            data_ = data
        else: 
            data_ = pd.concat([data_, data])
    return data_

# %%
import seaborn as sns
import copy

def load_data():
    datas = list()
    save_path = "../Output/CIFAR100-fedavg-G*-N1*-*/s[1-9].csv"
    path_list = glob.glob(save_path)
    data_temp = get_concat_glob(path_list)
    data_temp["a1"] = data_temp["a1"] * 100
    data_temp["a3"] = data_temp["a3"] * 100
    data_temp['Distribution'] = data_temp['distribution'] .map({0: "Balanced IID partition", 
                                                0.3: "Balanced Dirichlet partition (α=0.3)", 
                                                })
    data_temp['Mode'] = data_temp['Mode'] .map({'fedavg0': "FedAvg", 
                                                'fedprox0': "FedProx", 
                                                'scaffold0': "Scaffold",  
                                                'feddyn0': "FedDyn", 
                                                'G11': "FedGN",
                                                'G01': "FedGN01",
                                                'FedAvg_F': "FedAvg_F",
                                                'FedGN_F': "FedGN_F",
                                               })
    print(data_temp["Mode"].unique())
    sk = ['FedAvg', "FedGN", "FedAvg_F", "FedGN_F"]
    data_temp = data_temp.set_index('Mode').loc[sk].reset_index()
    print(data_temp.size)
    return data_temp

# %%
data_temp = load_data()

fig, axes = plt.subplots(1, 2, figsize=(10,4.5), dpi=100, sharey=True)
sns.set_style("darkgrid")
ax = axes[0]

ax = axes[1]
temp = copy.deepcopy(data_temp)
temp = temp[temp["act_prob"] == 1.0]
temp = temp[(temp["Mode"]=="FedGN") | (temp["Mode"]=="FedAvg_F") | (temp["Mode"]=="FedAvg") | (temp["Mode"]=="FedGN_F")]
temp = temp[(temp["LR"] == 0.1) | (temp["LR"] == 1.2)]
temp = temp[(temp["Decay"] == "No") | (temp["Decay"] == "GN_No")]
print(temp.shape)
ax = sns.lineplot(data=temp, x="epoch", y="a3", ax=ax, hue="Mode", style="Distribution", errorbar="se")

ax.set_ylim([20,55])
fig.tight_layout()
# Out:
# ['FedAvg' 'FedGN' 'FedGN01' 'FedAvg_F' 'FedGN_F']
# 143264
# (1200, 22)

# %%
import seaborn as sns
import copy

def load_data():
    datas = list()
    save_path = "../Output/CIFAR10noBN2-fedavg-G*-N1*-*/s[1-9].csv"
    path_list = glob.glob(save_path)
    data_temp = get_concat_glob(path_list)
    data_temp["a1"] = data_temp["a1"] * 100
    data_temp["a3"] = data_temp["a3"] * 100
    data_temp['Distribution'] = data_temp['distribution'] .map({0: "Balanced IID partition", 
                                                0.3: "Balanced Dirichlet partition (α=0.3)", 
                                                })
    data_temp['Mode'] = data_temp['Mode'] .map({'fedavg0': "FedAvg", 
                                                'fedprox0': "FedProx", 
                                                'scaffold0': "Scaffold",  
                                                'feddyn0': "FedDyn", 
                                                'G11': "FedGN",
                                                'G01': "FedGN01",
                                                'FedAvg_F': "FedAvg_F",
                                                'FedGN_F': "FedGN_F",
                                               })
    print(data_temp["Mode"].unique())
    sk = ['FedAvg', "FedGN", "FedAvg_F", "FedGN_F"]
    data_temp = data_temp.set_index('Mode').loc[sk].reset_index()
    print(data_temp.size)
    return data_temp

# %%
data_temp = load_data()

fig, axes = plt.subplots(1, 2, figsize=(10,4.5), dpi=100, sharey=True)
sns.set_style("darkgrid")
ax = axes[0]

ax = axes[1]
temp = copy.deepcopy(data_temp)
temp = temp[temp["act_prob"] == 1.0]
temp = temp[(temp["Mode"]=="FedGN") | (temp["Mode"]=="FedAvg_F") | (temp["Mode"]=="FedAvg") | (temp["Mode"]=="FedGN_F")]
temp = temp[(temp["LR"] == 0.1) | (temp["LR"] == 1.2)]
temp = temp[(temp["Decay"] == "No") | (temp["Decay"] == "GN_No")]
print(temp.shape)
ax = sns.lineplot(data=temp, x="epoch", y="a3", ax=ax, hue="Mode", style="Distribution", errorbar="se")

# ax.set_ylim([20,55])
fig.tight_layout()
# Out:
# ['FedGN' 'FedGN_F' 'FedAvg' 'FedAvg_F']
# 84700
# (750, 22)
