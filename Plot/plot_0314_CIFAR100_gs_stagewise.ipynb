# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.cm as cm
import os
import seaborn as sns
import glob
import natsort

# %%
import seaborn as sns
import copy

def load_data(save_path):
    datas = list()
    path_list = glob.glob(save_path)
    data_temp = get_concat_glob(path_list)
    data_temp["a1"] = data_temp["a1"] * 100
    data_temp["a3"] = data_temp["a3"] * 100
    data_temp['Distribution'] = data_temp['distribution'] .map({0: "IID partition", 
                                                0.3: "Non-IID partition (α=0.3)", 
                                                })
    # sk = [0, 0.1, 0.01, 0.001]
    # data_temp = data_temp.set_index('Scaling').loc[sk].reset_index()
    # print(data_temp.size)
    return data_temp

# %%
def get_concat_glob(paths):
    data_ = []
    for i, path in enumerate(paths):

        if "LN" in path: continue
        if "WD" in path: continue
        if "FCs" in path: continue
        if "G1" in path: continue
        if "Mean" in path: continue

        data = pd.read_csv(path)
        data["Mode"] = data["mode"]
        data["Scaling"] = "vanilla"

        if "Mean1" in path:
            data["Mode"] += "+M1"
            continue
        elif "Mean2" in path:
            data["Mode"] += "+M2"
            continue
        elif "Mean5" in path:
            data["Mode"] += "+M5"
            continue
        else:
            # continue
            pass
        
        # if "G11" in path and "LR1.2" in path and "Mean" in path:
        #     data["Mode"] += "+G11 (LR1.2)"
        # elif "G11" in path and "LR1.5" in path and "Mean" in path:
        #     data["Mode"] += "+G11 (LR1.5)"
        # elif "G11" in path and "LR1.0" in path and "Mean" in path:
        #     data["Mode"] += "+G11 (LR1.0)"
        # elif "G11" in path and "LR0.8" in path and "Mean" in path:
        #     data["Mode"] += "+G11 (LR0.8)"
        # elif "G11" in path and "LR0.6" in path and "Mean" in path:
        #     data["Mode"] += "+G11 (LR0.6)"
        # elif "G11" in path and "LR0.3" in path and "Mean" in path:
        #     data["Mode"] += "+G11 (LR0.3)"
        # elif "G11" in path: continue

        if "gs11L" in path: continue
            # data["Mode"] += "+gs11"
            # continue
        elif "gs12L" in path: 
            continue
        elif "gs21L" in path: continue
        elif "gs22L" in path: continue
        elif "gs31L" in path: 
            data["Mode"] += "+gs31"
            continue
            # continue
        elif "gs32L" in path: 
            data["Mode"] += "+gs32"
            continue
        elif "gs4112L" in path: 
            data["Scaling"] = "x 0.001 (4112)"
        elif "gs4113L" in path: 
            data["Scaling"] = "x 0.001 (4113)"
        elif "gs4114L" in path: 
            data["Scaling"] = "x 0.001 (4114)"
        elif "gs411L" in path: 
            data["Scaling"] = "x 0.01"
            # continue
        elif "gs4122L" in path: 
            data["Scaling"] = "x 0.001 (4122)"
        elif "gs4123" in path: 
            data["Scaling"] = "x 0.001 (4123)"
        elif "gs4124L" in path: 
            data["Scaling"] = "x 0.001 (4124)"
        elif "gs4125" in path: 
            data["Scaling"] = "x 0.001 (4125)"
        elif "gs4126" in path: 
            data["Scaling"] = "x 0.001 (4126)"
        elif "gs412L" in path: 
            data["Scaling"] = "x 0.001"
        elif "gs41260" in path: 
            data["Scaling"] = "x 0.001 (41260)"
        elif "gs4411" in path: 
            data["Scaling"] = "x 0.001 (4411)"
        elif "gs4412" in path: 
            data["Scaling"] = "x 0.001 (4412)"
        elif "gs4413" in path: 
            data["Scaling"] = "x 0.001 (4413)"
        elif "gs4414" in path: 
            data["Scaling"] = "x 0.001 (4414)"
        elif "gs4415" in path: 
            data["Scaling"] = "x 0.001 (4415)"

        elif "gs4421" in path: 
            data["Scaling"] = "x 0.001 (4421)"
        elif "gs4422" in path: 
            data["Scaling"] = "x 0.001 (4422)"
        elif "gs4423" in path: 
            data["Scaling"] = "x 0.001 (4423)"
        elif "gs4424" in path: 
            data["Scaling"] = "x 0.001 (4424)"
        
        elif "gs4431" in path: 
            data["Scaling"] = "x 0.001 (4431)"
        elif "gs4432" in path: 
            data["Scaling"] = "x 0.001 (4432)"
        elif "gs4433" in path: 
            data["Scaling"] = "x 0.001 (4433)"
        elif "gs4434" in path: 
            data["Scaling"] = "x 0.001 (4434)"
        
        elif "gs4442" in path: 
            data["Scaling"] = "x 0.001 (4442)"
        elif "gs4443" in path: 
            data["Scaling"] = "x 0.001 (4443)"
        elif "gs4445" in path: 
            data["Scaling"] = "x 0.001 (4445)"
        elif "gs4448" in path: 
            data["Scaling"] = "x 0.001 (4448)"
        elif "gs44410" in path: 
            data["Scaling"] = "x 0.001 (44410)"
        
        elif "gs4461" in path: 
            data["Scaling"] = "x 0.001 (4461)"
        elif "gs4462" in path: 
            data["Scaling"] = "x 0.001 (4462)"
        elif "gs4463" in path: 
            data["Scaling"] = "x 0.001 (4463)"
        elif "gs4464" in path: 
            data["Scaling"] = "x 0.001 (4464)"
        elif "gs4471" in path: 
            data["Scaling"] = "x 0.001 (4471)"
        elif "gs4472" in path: 
            data["Scaling"] = "x 0.001 (4472)"        
        
        elif "gs51" in path: 
            data["Scaling"] = "x 0.001 (51)"

        elif "gs414L" in path: 
            data["Scaling"] = "x 0.001 (x1.5)"
            continue
        elif "gs41L" in path: 
            data["Scaling"] = "x 0.1"
            continue
        elif "gs421L" in path: 
            data["Mode"] += "+gs421"
            continue
        elif "gs431L" in path: 
            data["Scaling"] += "+gs431"
            continue
        elif "gs432L" in path: 
            data["Scaling"] += "+gs432"
            continue
        elif "gs41L" in path: 
            data["Mode"] += "+gs41"
            continue
        elif "gs42L" in path: 
            data["Mode"] += "+gs42"
            continue
        elif "gs711L" in path: 
            data["Scaling"] += "+gs711"
            continue
        elif "gs712L" in path: 
            data["Scaling"] += "+gs712"
            continue
        elif "gs713L" in path: 
            data["Scaling"] += "+gs713"
            continue
        elif "gs715L" in path: 
            data["Scaling"] += "+gs715"
            continue
        elif "gs716L" in path: 
            data["Scaling"] += "+gs716"
            continue
        elif "gs717L" in path: 
            data["Scaling"] += "+gs717"
            continue
        elif "gs714L" in path: 
            # data["Scaling"] += "+gs714"
            continue
        elif "gs811L" in path: 
            data["Scaling"] += "+gs811"
            continue
        elif "gs821L" in path: 
            data["Scaling"] += "+gs821"
            continue
        elif "gs" in path:
            continue
        # elif "gs61L0.01L0.1" in path: 
        #     data["Scaling"] = "gs61L0.01L0.1"
        # elif "gs61L0.01L0.01" in path: 
        #     data["Scaling"] = "gs61L0.01L0.01"
        # elif "gs61L0.01L0.001" in path: 
        #     data["Scaling"] = "gs61L0.01L0.001"

        if "hs11" in path:
            data["Scaling"] += "+hs11"



        if len(data_) == 0: 
            # print(path)
            data_ = data
        else: 
            # print(path)
            data_ = pd.concat([data_, data])
    return data_

# %%
data_temp = load_data("../Output/CIFAR100-*B0-D0*-N100-P0.01*/s[1-9].csv")

fig, axes = plt.subplots(1, 2, figsize=(14,4), dpi=200, sharey=True)
sns.set_style("darkgrid")
for index, name, iid in zip(range(2), ["fedavg", "fedavg"], [0, 0.3]):
    ax = axes[index]
    temp = copy.deepcopy(data_temp)
    temp = temp[temp["act_prob"] == 0.01]
    temp = temp[temp["epoch"] <= 999]
    if iid == 0.: temp = temp[(temp["Distribution"] == "IID partition")]
    elif iid == 0.3: temp = temp[(temp["Distribution"] != "IID partition")]
    temp = temp[(temp["Mode"] == name)]
    # sk = ["vanilla", "x 0.001", "x 0.001 (41253)", "x 0.001 (41260)", "x 0.001 (4114)", "x 0.001 (4122)", "x 0.001 (4123)", "x 0.001 (4124)"]
    sk = ["vanilla", "x 0.001 (4414)", "x 0.001 (4411)", "x 0.001 (4412)", "x 0.001 (4413)",  "x 0.001 (4122)", "x 0.001 (4123)", "x 0.001 (4124)"]
    temp = temp.set_index('Scaling').loc[sk].reset_index()
    ax = sns.lineplot(data=temp, x="epoch", y="a3", hue="Scaling", ax=ax, palette="tab10", errorbar="se", linewidth = 0.8)
    ax.set_ylim([20, 55])
    ax.set_ylabel("Test Accuracy (%)")
    ax.set_title(name)
    ax.set_xlabel("# communications")
plt.pause(0.1)
# break

# %%
data_temp = load_data("../Output/CIFAR100-*B0-D0*-N100-P0.01*/s[1-9].csv")

fig, axes = plt.subplots(1, 2, figsize=(14,4), dpi=200, sharey=True)
sns.set_style("darkgrid")
for index, name, iid in zip(range(2), ["fedavg", "fedavg"], [0, 0.3]):
    ax = axes[index]
    temp = copy.deepcopy(data_temp)
    temp = temp[temp["act_prob"] == 0.01]
    temp = temp[temp["epoch"] == 999]
    if iid == 0.: temp = temp[(temp["Distribution"] == "IID partition")]
    elif iid == 0.3: temp = temp[(temp["Distribution"] != "IID partition")]
    temp = temp[(temp["Mode"] == name)]
    # sk = ["vanilla", "x 0.001", "x 0.001 (41253)", "x 0.001 (41260)", "x 0.001 (4114)", "x 0.001 (4122)", "x 0.001 (4123)", "x 0.001 (4124)"]
    sk = ["vanilla", "x 0.01", "x 0.001", "x 0.001 (4411)", "x 0.001 (4412)", "x 0.001 (4413)", "x 0.001 (4122)", "x 0.001 (4123)", "x 0.001 (4124)"]
    temp = temp.set_index('Scaling').loc[sk].reset_index()
    # ax = sns.lineplot(data=temp, x="epoch", y="a3", hue="Scaling", ax=ax, palette="tab10", errorbar="se", linewidth = 0.8)
    ax = sns.barplot(data=temp, x="Scaling", y="a3", ax=ax, palette="tab10", errorbar="se", linewidth = 0.8)
    ax.set_ylim([40,55])
    ax.set_ylabel("Test Accuracy (%)")
    ax.set_title(name)
    ax.set_xlabel("# communications")
    ax.set_xticklabels(ax.get_xticklabels(), rotation = 40)
plt.pause(0.1)
# break

# %%
data_temp = load_data("../Output/CIFAR10-*-N100-P0.01*/s[1-9].csv")
data_temp2 = load_data("../Output/CIFAR10noBN2-*-N100-*/s[1-9].csv")
data_temp = pd.concat([data_temp, data_temp2])

fig, axes = plt.subplots(1, 2, figsize=(14,4), dpi=200, sharey=True)
sns.set_style("darkgrid")
for index, name, iid in zip(range(2), ["fedavg", "fedavg"], [0, 0.3]):
    # if index == 0 : continue
    ax = axes[index]
    temp = copy.deepcopy(data_temp)
    temp = temp[temp["act_prob"] == 0.01]
    temp = temp[temp["epoch"] <= 499]
    if iid == 0.: temp = temp[(temp["Distribution"] == "IID partition")]
    elif iid == 0.3: temp = temp[(temp["Distribution"] != "IID partition")]
    temp = temp[(temp["Mode"] == name)]
    # sk = ["vanilla", "x 0.001", "x 0.001 (4112)", "x 0.001 (4113)", "x 0.001 (4114)", "x 0.001 (4122)", "x 0.001 (4123)", "x 0.001 (4124)"]
    # sk = ["vanilla", "x 0.001", "x 0.001 (4411)",  "x 0.001 (4122)", "x 0.001 (4123)", "x 0.001 (4124)"]
    # sk = ["vanilla", "x 0.01", "x 0.001", "x 0.001 (4411)", "x 0.001 (4412)", "x 0.001 (4413)",  "x 0.001 (4122)", "x 0.001 (4123)", "x 0.001 (4124)"]
    
    if index == 0:
        sk = ["vanilla", "x 0.001 (4415)", "x 0.001 (4414)", "x 0.001 (4411)", "x 0.001 (4412)", "x 0.001 (4421)", "x 0.001 (4422)", "x 0.001 (4423)", "x 0.001 (4424)"]
        sk = ["vanilla", "x 0.001 (4461)", "x 0.001 (4434)", "x 0.001 (4415)", "x 0.001 (4414)", "x 0.001 (4411)", "x 0.001 (4412)"]
        sk = ["vanilla", "x 0.001 (4471)", "x 0.001 (4411)", "x 0.001 (4122)", "x 0.001 (4123)", "x 0.001 (4124)", "x 0.001 (4125)", "x 0.001 (4126)"]
    if index == 1:
        sk = ["vanilla", "x 0.001 (4415)", "x 0.001 (4414)", "x 0.001 (4411)", "x 0.001 (4412)", "x 0.001 (4421)", "x 0.001 (4422)", "x 0.001 (4423)", "x 0.001 (4424)"]
        sk = ["vanilla", "x 0.001 (4461)", "x 0.001 (4434)", "x 0.001 (4415)", "x 0.001 (4414)", "x 0.001 (4411)", "x 0.001 (4412)"]
        sk = ["vanilla", "x 0.001 (4471)", "x 0.001 (4411)", "x 0.001 (4122)", "x 0.001 (4123)", "x 0.001 (4124)", "x 0.001 (4125)", "x 0.001 (4126)"]
    temp = temp.set_index('Scaling').loc[sk].reset_index()
    ax = sns.lineplot(data=temp, x="epoch", y="a3", hue="Scaling", ax=ax, palette="tab10", errorbar=None, linewidth = 0.8)
    ax.set_ylim([60,82])
    ax.set_ylabel("Test Accuracy (%)")
    ax.set_title(name)
    ax.set_xlabel("# communications")
    break
plt.pause(0.1)

# %%
temp["Scaling"].unique()
# Out:
# array(['x 0.001 (4421)', 'x 0.001 (4423)', 'x 0.001 (4414)',
#        'x 0.001 (4112)', 'x 0.001 (4413)', 'x 0.001 (4123)',
#        'x 0.001 (4424)', 'x 0.001 (4471)', 'x 0.01', 'x 0.001 (4433)',
#        'x 0.001 (4415)', 'x 0.001 (4461)', 'x 0.001 (4124)',
#        'x 0.001 (4411)+hs11', 'x 0.001 (4114)', 'x 0.001',
#        'x 0.001 (4126)', 'x 0.001 (4434)', 'x 0.001 (51)',
#        'x 0.001 (4432)', 'x 0.001 (4113)', 'x 0.001 (4422)',
#        'x 0.001 (4431)', 'x 0.001 (4125)', 'x 0.001 (4411)',
#        'x 0.001 (4122)', 'x 0.001 (4412)', 'vanilla'], dtype=object)

# %%
data_temp = load_data("../Output/CIFAR10-*-N100-P0.01*/s[1-9].csv")
data_temp2 = load_data("../Output/CIFAR10noBN2-*-N100-*/s[1-9].csv")
data_temp = pd.concat([data_temp, data_temp2])

fig, axes = plt.subplots(1, 2, figsize=(12,4), dpi=200, sharey=True)
sns.set_style("darkgrid")
for index, name, iid in zip(range(2), ["fedavg", "fedavg"], [0, 0.3]):
    ax = axes[index]
    temp = copy.deepcopy(data_temp)
    temp = temp[temp["act_prob"] == 0.01]
    temp = temp[temp["epoch"] == 499]
    if iid == 0.: temp = temp[(temp["Distribution"] == "IID partition")]
    elif iid == 0.3: temp = temp[(temp["Distribution"] != "IID partition")]
    temp = temp[(temp["Mode"] == name)]
    # sk = ["vanilla", "x 0.001", "x 0.001 (4112)", "x 0.001 (4113)", "x 0.001 (4114)", "x 0.001 (4122)", "x 0.001 (4123)", "x 0.001 (4124)"]
    # temp = temp.set_index('Scaling').loc[sk].reset_index()
    # sk = ["vanilla", "x 0.001", "x 0.001 (4411)",  "x 0.001 (4122)", "x 0.001 (4123)", "x 0.001 (4124)"]
    sk = ["vanilla", "x 0.01", "x 0.001", "x 0.001 (4411)", "x 0.001 (4412)", "x 0.001 (4413)",  "x 0.001 (4122)", "x 0.001 (4123)", "x 0.001 (4124)"]
    # if index == 0:
    #     sk = ["vanilla", "x 0.001 (4415)", "x 0.001 (4414)", "x 0.001 (4411)", "x 0.001 (4412)", "x 0.001 (4413)", "x 0.001 (4421)", "x 0.001 (4422)", "x 0.001 (4423)", "x 0.001 (4424)", "x 0.001 (4123)", "x 0.001 (4124)"]
    # if index == 1:
    # With GradNorm
    sk = ["vanilla", "x 0.001 (4415)", "x 0.001 (4414)", "x 0.001 (4411)", "x 0.001 (4412)", "x 0.001 (4413)", "x 0.001 (4421)", "x 0.001 (4422)", "x 0.001 (4423)", "x 0.001 (4424)", "x 0.001 (4123)", "x 0.001 (4124)"]
    sk = ["vanilla", "x 0.001 (4415)", "x 0.001 (4414)", "x 0.001 (4411)", "x 0.001 (4412)", "x 0.001 (4413)", "x 0.001 (4123)", "x 0.001 (4124)"]
    temp = temp.set_index('Scaling').loc[sk].reset_index()
    # ax = sns.lineplot(data=temp, x="epoch", y="a3", hue="Scaling", ax=ax, palette="tab10", errorbar="se", linewidth = 0.8)
    ax = sns.barplot(data=temp, x="Scaling", y="a3", ax=ax, palette="tab10", errorbar="se", linewidth = 0.8)
    ax.set_ylim([76,82])
    ax.set_ylabel("Test Accuracy (%)")
    ax.set_title(name)
    ax.set_xlabel("# communications")
    ax.set_xticklabels(ax.get_xticklabels(), rotation = 40)
plt.pause(0.1)
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 25
#      23 sk = ["vanilla", "x 0.001 (4415)", "x 0.001 (4414)", "x 0.001 (4411)", "x 0.001 (4412)", "x 0.001 (4413)", "x 0.001 (4421)", "x 0.001 (4422)", "x 0.001 (4423)", "x 0.001 (4424)", "x 0.001 (4123)", "x 0.001 (4124)"]
#      24 sk = ["vanilla", "x 0.001 (4415)", "x 0.001 (4414)", "x 0.001 (4414)+hs11", "x 0.001 (4411)", "x 0.001 (4412)", "x 0.001 (4413)", "x 0.001 (4123)", "x 0.001 (4124)"]
# ---> 25 temp = temp.set_index('Scaling').loc[sk].reset_index()
#      26 # ax = sns.lineplot(data=temp, x="epoch", y="a3", hue="Scaling", ax=ax, palette="tab10", errorbar="se", linewidth = 0.8)
#      27 ax = sns.barplot(data=temp, x="Scaling", y="a3", ax=ax, palette="tab10", errorbar="se", linewidth = 0.8)
#
# File ~/anaconda3/envs/PT12/lib/python3.10/site-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/envs/PT12/lib/python3.10/site-packages/pandas/core/indexing.py:1301, in _LocIndexer._getitem_axis(self, key, axis)
#    1298     if hasattr(key, "ndim") and key.ndim > 1:
#    1299         raise ValueError("Cannot index with multidimensional key")
# -> 1301     return self._getitem_iterable(key, axis=axis)
#    1303 # nested tuple slicing
#    1304 if is_nested_tuple(key, labels):
#
# File ~/anaconda3/envs/PT12/lib/python3.10/site-packages/pandas/core/indexing.py:1239, in _LocIndexer._getitem_iterable(self, key, axis)
#    1236 self._validate_key(key, axis)
#    1238 # A collection of keys
# -> 1239 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1240 return self.obj._reindex_with_indexers(
#    1241     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1242 )
#
# File ~/anaconda3/envs/PT12/lib/python3.10/site-packages/pandas/core/indexing.py:1432, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1429 ax = self.obj._get_axis(axis)
#    1430 axis_name = self.obj._get_axis_name(axis)
# -> 1432 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1434 return keyarr, indexer
#
# File ~/anaconda3/envs/PT12/lib/python3.10/site-packages/pandas/core/indexes/base.py:6113, in Index._get_indexer_strict(self, key, axis_name)
#    6110 else:
#    6111     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6113 self._raise_if_missing(keyarr, indexer, axis_name)
#    6115 keyarr = self.take(indexer)
#    6116 if isinstance(key, Index):
#    6117     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/envs/PT12/lib/python3.10/site-packages/pandas/core/indexes/base.py:6176, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6173     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6175 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6176 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['x 0.001 (4414)+hs11'] not in index"

# %%
data_temp["Scaling"].unique()
# Out:
# array(['x 0.01', 'x 0.001 (4414)', 'x 0.001 (4421)', 'x 0.001 (4423)',
#        'x 0.001 (4112)', 'x 0.001 (4413)', 'x 0.001 (4114)',
#        'x 0.001 (4123)', 'x 0.001 (4424)', 'x 0.001 (4471)',
#        'x 0.001 (4411)', 'x 0.001 (4433)', 'x 0.001 (4122)',
#        'x 0.001 (4415)', 'x 0.001 (4126)', 'x 0.001 (4125)',
#        'x 0.001 (4124)', 'x 0.001', 'x 0.001 (4461)',
#        'x 0.001 (4411)+hs11', 'x 0.001 (4434)', 'x 0.001 (4412)',
#        'x 0.001 (51)', 'x 0.001 (4113)', 'x 0.001 (4432)',
#        'x 0.001 (4422)', 'x 0.001 (4431)', 'vanilla'], dtype=object)

# %%
data_temp = load_data("../Output/CIFAR10-*-N100-P0.01*/s[1-9].csv")
data_temp2 = load_data("../Output/CIFAR10noBN2-*-N100-*/s[1-9].csv")
data_temp = pd.concat([data_temp, data_temp2])

fig, axes = plt.subplots(1, 2, figsize=(12,4), dpi=200, sharey=True)
sns.set_style("darkgrid")
for index, name, iid in zip(range(2), ["fedavg", "fedavg"], [0, 0.3]):
    ax = axes[index]
    temp = copy.deepcopy(data_temp)
    temp = temp[temp["act_prob"] == 0.01]
    temp = temp[temp["epoch"] == 499]
    if iid == 0.: temp = temp[(temp["Distribution"] == "IID partition")]
    elif iid == 0.3: temp = temp[(temp["Distribution"] != "IID partition")]
    temp = temp[(temp["Mode"] == name)]
    sk = ["vanilla", "x 0.001 (4415)", "x 0.001 (4414)", "x 0.001 (4411)", "x 0.001 (4412)", 
                        "x 0.001 (4421)", "x 0.001 (4422)", "x 0.001 (4423)", "x 0.001 (4424)", 
                        "x 0.001 (4413)", "x 0.001 (4421)", "x 0.001 (4422)", "x 0.001 (4423)", "x 0.001 (4424)"]
    # if index == 0:
    #     sk = ["vanilla", "x 0.001 (4415)", "x 0.001 (4414)", "x 0.001 (4411)", "x 0.001 (4412)", 
    #                      "x 0.001 (4421)", "x 0.001 (4422)", "x 0.001 (4423)", "x 0.001 (4424)", 
    #                      "x 0.001 (4413)", "x 0.001 (4421)", "x 0.001 (4422)", "x 0.001 (4423)", "x 0.001 (4424)"]
    # if index == 1:
    #     sk = ["vanilla", "x 0.001 (4415)", "x 0.001 (4414)", "x 0.001 (4411)", "x 0.001 (4412)", "x 0.001 (4413)", "x 0.001 (4421)", "x 0.001 (4422)", "x 0.001 (4423)", "x 0.001 (4424)"]
    temp = temp.set_index('Scaling').loc[sk].reset_index()
    # ax = sns.lineplot(data=temp, x="epoch", y="a3", hue="Scaling", ax=ax, palette="tab10", errorbar="se", linewidth = 0.8)
    ax = sns.barplot(data=temp, x="Scaling", y="a3", ax=ax, palette="tab10", errorbar="se", linewidth = 0.8)
    ax.set_ylim([75,82])
    ax.set_ylabel("Test Accuracy (%)")
    ax.set_title(name)
    ax.set_xlabel("# communications")
    ax.set_xticklabels(ax.get_xticklabels(), rotation = 40)
plt.pause(0.1)
fig.tight_layout()

# %% [markdown]
# ## Single

# %%
data_temp = load_data("../Output/CIFAR10-*-N100-P0.01*/s[1-9].csv")
data_temp2 = load_data("../Output/CIFAR10noBN2-*-N100-*/s[1-9].csv")
data_temp = pd.concat([data_temp, data_temp2])

fig, axes = plt.subplots(1, 1, figsize=(14,7), dpi=200, sharey=True)
axes = [axes]
sns.set_style("darkgrid")
for index, name, iid in zip(range(2), ["fedavg", "fedavg"], [0]):
    # if index == 0 : continue
    ax = axes[index]
    temp = copy.deepcopy(data_temp)
    temp = temp[temp["act_prob"] == 0.01]
    temp = temp[temp["epoch"] <= 499]
    if iid == 0.: temp = temp[(temp["Distribution"] == "IID partition")]
    elif iid == 0.3: temp = temp[(temp["Distribution"] != "IID partition")]
    temp = temp[(temp["Mode"] == name)]
    sk = ["vanilla", "x 0.001 (4431)", "x 0.001 (4432)", "x 0.001 (4433)", "x 0.001 (4411)"]
    temp = temp.set_index('Scaling').loc[sk].reset_index()
    ax = sns.lineplot(data=temp, x="epoch", y="a3", hue="Scaling", ax=ax, palette="tab10", errorbar=None, linewidth = 0.8)
    ax.set_ylim([20,82])
    ax.set_ylabel("Test Accuracy (%)")
    ax.set_title(name)
    ax.set_xlabel("# communications")
    # break
plt.pause(0.1)

# %% [markdown]
# ## Make Plots

# %%
data_temp = load_data("../Output/CIFAR100-*-N100-P0.01*/s[1-9].csv")
# data_temp2 = load_data("../Output/CIFAR10noBN2-*-N100-*/s[1-9].csv")
# data_temp = pd.concat([data_temp, data_temp2])

fig, axes = plt.subplots(1, 2, figsize=(10,4), dpi=200, sharey=True)
sns.set_style("darkgrid")
for index, name, iid in zip(range(2), ["fedavg", "fedavg"], [0, 0.3]):
    ax = axes[index]
    temp = copy.deepcopy(data_temp)
    temp = temp[temp["act_prob"] == 0.01]
    temp = temp[temp["epoch"] == 999]
    if iid == 0.: temp = temp[(temp["Distribution"] == "IID partition")]
    elif iid == 0.3: temp = temp[(temp["Distribution"] != "IID partition")]
    temp = temp[(temp["Mode"] == name)]
    sk = ["vanilla", "x 0.001 (4414)", "x 0.001 (4411)", "x 0.001 (4412)", "x 0.001 (4413)"]
    temp = temp.set_index('Scaling').loc[sk].reset_index()
    temp['Scaling'] = temp['Scaling'].replace(['x 0.001 (4414)', 'x 0.001 (4411)', 'x 0.001 (4412)', 'x 0.001 (4413)'], 
                                              ['2', '3', '5', '8'])
    ax = sns.barplot(data=temp, x="Scaling", y="a3", ax=ax, palette="tab10", errorbar="se", linewidth = 0.8)
    ax.set_ylim([45,55])
    ax.set_ylabel("Test Accuracy (%)")
    if index == 0: ax.set_title("IID Label Distribution (FedAvg)")
    elif index == 1: ax.set_title("Non-IID Label Distribution (FedAvg)")
    ax.set_xlabel("Sequentially Unfrozen A Layer Every # Epochs")
    ax.set_xticklabels(ax.get_xticklabels(), rotation = 40)
fig.tight_layout()
plt.pause(0.1)

# %%
data_temp = load_data("../Output/CIFAR10-*-N100-P0.01*/s[1-9].csv")
data_temp2 = load_data("../Output/CIFAR10noBN2-*-N100-*/s[1-9].csv")
data_temp = pd.concat([data_temp, data_temp2])

fig, axes = plt.subplots(1, 2, figsize=(10,4), dpi=200, sharey=True)
sns.set_style("darkgrid")
for index, name, iid in zip(range(2), ["fedavg", "fedavg"], [0, 0.3]):
    ax = axes[index]
    temp = copy.deepcopy(data_temp)
    temp = temp[temp["act_prob"] == 0.01]
    temp = temp[temp["epoch"] == 499]
    if iid == 0.: temp = temp[(temp["Distribution"] == "IID partition")]
    elif iid == 0.3: temp = temp[(temp["Distribution"] != "IID partition")]
    temp = temp[(temp["Mode"] == name)]
    sk = ["vanilla", "x 0.001 (4415)", "x 0.001 (4414)", "x 0.001 (4411)", "x 0.001 (4412)", "x 0.001 (4413)"]
    temp = temp.set_index('Scaling').loc[sk].reset_index()
    temp['Scaling'] = temp['Scaling'].replace(['x 0.001 (4415)', 'x 0.001 (4414)', 'x 0.001 (4411)', 'x 0.001 (4412)', 'x 0.001 (4413)'], 
                                              ['1', '2', '3', '5', '8'])
    ax = sns.barplot(data=temp, x="Scaling", y="a3", ax=ax, palette="tab10", errorbar="se", linewidth = 0.8)
    ax.set_ylim([76,82])
    ax.set_ylabel("Test Accuracy (%)")
    if index == 0: ax.set_title("IID Label Distribution (FedAvg)")
    elif index == 1: ax.set_title("Non-IID Label Distribution (FedAvg)")
    ax.set_xlabel("Sequentially Unfrozen A Layer Every # Epochs")
    ax.set_xticklabels(ax.get_xticklabels(), rotation = 40)
fig.tight_layout()
plt.pause(0.1)

# %%
## Test others

# %%
data_temp = load_data("../Output/CIFAR10-*-N100-P0.01*/s[1-9].csv")
data_temp2 = load_data("../Output/CIFAR10noBN2-*-N100-*/s[1-9].csv")
data_temp = pd.concat([data_temp, data_temp2])

fig, axes = plt.subplots(1, 2, figsize=(10,4), dpi=200, sharey=True)
sns.set_style("darkgrid")
for index, name, iid in zip(range(2), ["fedavg", "fedavg"], [0, 0.3]):
    ax = axes[index]
    temp = copy.deepcopy(data_temp)
    temp = temp[temp["act_prob"] == 0.01]
    temp = temp[temp["epoch"] == 499]
    if iid == 0.: temp = temp[(temp["Distribution"] == "IID partition")]
    elif iid == 0.3: temp = temp[(temp["Distribution"] != "IID partition")]
    temp = temp[(temp["Mode"] == name)]
    sk = ["vanilla", "x 0.001 (4442)", "x 0.001 (4443)", "x 0.001 (4445)", "x 0.001 (4448)", "x 0.001 (44410)", 
          "x 0.001 (4421)", "x 0.001 (4422)", "x 0.001 (4423)",
        #   "x 0.001 (4471)", 
        #   "x 0.001 (4472)"
          ]
    temp = temp.set_index('Scaling').loc[sk].reset_index()
    # temp['Scaling'] = temp['Scaling'].replace(['x 0.001 (4415)', 'x 0.001 (4414)', 'x 0.001 (4411)', 'x 0.001 (4412)', 'x 0.001 (4413)'], 
    #                                           ['1', '2', '3', '5', '8'])
    ax = sns.barplot(data=temp, x="Scaling", y="a3", ax=ax, palette="tab10", errorbar="se", linewidth = 0.8)
    ax.set_ylim([76,82])
    ax.set_ylabel("Test Accuracy (%)")
    if index == 0: ax.set_title("IID Label Distribution (FedAvg)")
    elif index == 1: ax.set_title("Non-IID Label Distribution (FedAvg)")
    ax.set_xlabel("Sequentially Unfrozen A Layer Every # Epochs")
    ax.set_xticklabels(ax.get_xticklabels(), rotation = 40)
fig.tight_layout()
plt.pause(0.1)

# %%
elif args.gs in [4471, 4472, 4473]:
    args.gs_clf = 0.001
    args.gs_enc = 1
    if args.gs == 4471: factor = 3
    elif args.gs == 4472: factor = 5
    elif args.gs == 4473: factor = 8
    if   "conv1" in p1 and (args.local_epoch * 10 + args.local_iter) // factor <= 0: p2.grad.data *= args.gs_clf
    elif "conv2" in p1 and (args.local_epoch * 10 + args.local_iter) // factor <= 1: p2.grad.data *= args.gs_clf
    elif "conv3" in p1 and (args.local_epoch * 10 + args.local_iter) // factor <= 2: p2.grad.data *= args.gs_clf
    elif "fc1"   in p1 and (args.local_epoch * 10 + args.local_iter) // factor <= 3: p2.grad.data *= args.gs_clf
    elif "fc2"   in p1 and (args.local_epoch * 10 + args.local_iter) // factor <= 4: p2.grad.data *= args.gs_clf
    elif "fc3"   in p1 and (args.local_epoch * 10 + args.local_iter) // factor <= 5: p2.grad.data *= args.gs_clf
    else: p2.grad.data *= args.gs_enc
